# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
temp = [14.2, 16.4, 11.9, 15.2, 18.5, 22.1, 19.4, 25.1, 23.4, 18.1, 22.6, 17.2]
sales = [215, 325, 185, 332, 406, 522, 412, 614, 544, 421, 445, 408]

# %%
# Tell matplotlib to create a scatter plot based upon the above data
plt.scatter(temp, sales, marker= "o", facecolors="red", edgecolors="black", s=temp, alpha=0.80)
stdv= np.std(sales)
stdv2= np.std(temp)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Set the upper and lower limits of our y axis
plt.ylim(min(sales)- stdv, max(sales)+stdv)
# Out:
# (64.32311852628017, 734.6768814737198)

# %%
# Set the upper and lower limits of our x axis
plt.xlim(min(temp)- stdv2,max(temp)+stdv2)
# Out:
# (8.05961698958728, 28.940383010412724)

# %%
# Create a title, x label, and y label for our chart
plt.title("Ice Cream Sales V Temperature")
plt.xlabel("Temperature(Celsius)")
plt.ylabel("Sales($)")
plt.show()

# %%
# Save an image of the chart and print to screen
plt.savefig("../images/4_chart.png")
# NOTE: If your plot shrinks after saving an image,

# update matplotlib to 2.2 or higher,
# or simply run the above cells again.
